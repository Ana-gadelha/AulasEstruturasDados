# %% [markdown]
# <a href="https://colab.research.google.com/github/Ana-gadelha/AulasEstruturasDados/blob/master/LendoArquivosPDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Professor: Ricardo Roberto de Lima - Lendo arquivos em PDF
# ### Vamos ler arquivos que possuem texto e arquivos que possuem imagem de tabelas

# %%
# !pip install PyPDF2
# !pip install tabula-py
# !pip install jpype1

# %%
# Importando os pacotes necessários
# Caso não tenha os pacotes PyPDF2 e tabula-py instalados, instale-os com os comandos abaixo
# !pip install PyPDF2
# !pip install tabula-py

import tabula
import PyPDF2

import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install PyPDF2

# %%
# !pip install tabula-py

# %%
# !pip install jpype1

# %% [markdown]
# ### Primeiro vamos ler o arquivo PDF que possui imagem de tabelas

# %%
# Carregando o arquivo PDF
lista_tabelas = tabula.read_pdf('arquivo2.pdf', pages = 'all')

# %%
# Exibindo quantas páginas foram carregadas
print(len(lista_tabelas))
# Out:
# 3

# %%
# Gerando um Loop FOR para exibir cada página do PDF
for tabela in lista_tabelas:
    display(tabela)
# Out:
#                                  Descrição  Var. em relação ao tri. anterior  \
# 0           População Economicamente Ativa                               0.6
# 1                        População Ocupada                               1.6
# 2  Empregado no setor privado com carteira                               2.0
# 3  Empregado no setor privado sem carteira                               3.6
# 4                    Trabalhador doméstico                               2.0
# 5               Empregado no Setor Público                               1.9
# 6                               Empregador                               3.9
# 7                            Conta-própria                              -0.2
#
#    Var. em relação ao mesmo tri. do ano anterior  Var. em 4 trimestre (*)  \
# 0                                            5.4                      5.1
# 1                                            9.4                      6.4
# ...

# %%
# Obtendo somente a página 1. Lembre-se que no Python o índice começa em zero, por isso passamos o parametro zero abaixo
tabela1 = lista_tabelas[0]
tabela1
# Out:
#                                  Descrição  Var. em relação ao tri. anterior  \
# 0           População Economicamente Ativa                               0.6
# 1                        População Ocupada                               1.6
# 2  Empregado no setor privado com carteira                               2.0
# 3  Empregado no setor privado sem carteira                               3.6
# 4                    Trabalhador doméstico                               2.0
# 5               Empregado no Setor Público                               1.9
# 6                               Empregador                               3.9
# 7                            Conta-própria                              -0.2
#
#    Var. em relação ao mesmo tri. do ano anterior  Var. em 4 trimestre (*)  \
# 0                                            5.4                      5.1
# 1                                            9.4                      6.4
# ...

# %%
# Obtendo somente a página 2. Lembre-se que no Python o índice começa em zero, por isso passamos o parametro zero abaixo
tabela2 = lista_tabelas[1]
tabela2
# Out:
#                                    Descrição  \
# 0  Rendimento habitual de todos os trabalhos
# 1  Rendimento habitual do trabalho principal
# 2    Empregado no setor privado com carteira
# 3    Empregado no setor privado sem carteira
# 4                      Trabalhador doméstico
# 5                 Empregado no Setor Público
# 6                                 Empregador
# 7                              Conta-própria
#
#    Var. em relação ao tri. anterior  \
# 0                              -1.1
# 1                              -0.9
# 2                              -0.8
# 3                               1.4
# 4                               1.1
# 5                              -1.9
# 6                              -5.0
# 7                               0.1
#
#    Var. em relação ao mesmo tri. do ano anterior  Var. em 4 trimestre (*)  \
# 0                                           -9.7                     -7.7
# ...

# %%
# Obtendo somente a página 3. Lembre-se que no Python o índice começa em zero, por isso passamos o parametro zero abaixo
# Nesta terceira tabela precisamos tratar um pouquinho pra organizar nosso DataFrame
tabela3 = lista_tabelas[2]
tabela3
# Out:
#          Descrição (Milhões)        1SEM       2SEM VARIACAO_PERCENTUAL
# 0                  Descrição  1 semestre  2 semestr           1SEM 2SEM
# 1  Receita de vendas liquida         2.5        5.0            75% 100%
# 2          Custos e despesas         1.5        3.2             52% 89%
# 3     Despesas não previstas         1.2        1.4             12% 24%

# %%
# Listando todas as linhas, exceto a primeira linha com anotação de SLICE
tabela3 = tabela3[1:]
tabela3
# Out:
# Empty DataFrame
# Columns: [DESCRICAO, 1º SEMESTRE, 2º SEMESTRE, VAR_PERC_1_SEM, VAR_PERC_2_SEM]
# Index: []

# %%
tabela3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DESCRICAO       0 non-null      object
#  1   1º SEMESTRE     0 non-null      object
#  2   2º SEMESTRE     0 non-null      object
#  3   VAR_PERC_1_SEM  0 non-null      object
#  4   VAR_PERC_2_SEM  0 non-null      object
# dtypes: object(5)
# memory usage: 132.0+ bytes

# %%
# Separar a variacao percentual
# Cria coluna 0 e coluna 1 e os valores que serão colocados dentro será 1sem e 2sem
# Faz um SPLIT para separar no espaço, o comando STR é devido estarmos fazendo um tratamento em uma string
# Comando EXPAND separa e cria colunas novas
tabela3[[0, 1]] = tabela3['VARIACAO_PERCENTUAL'].str.split(" ", expand = True)
tabela3
# Out:
#          Descrição (Milhões) 1SEM 2SEM VARIACAO_PERCENTUAL    0     1
# 1  Receita de vendas liquida  2.5  5.0            75% 100%  75%  100%
# 2          Custos e despesas  1.5  3.2             52% 89%  52%   89%
# 3     Despesas não previstas  1.2  1.4             12% 24%  12%   24%

# %%
# Vamos excluir a coluna original com o comando DROP e utilizar o AXIS 1 (Eixo 1)
# Axis 1 = Colunas e Axis 2 = Linhas
tabela3 = tabela3.drop('VARIACAO_PERCENTUAL', axis = 1)
tabela3
# Out:
#          Descrição (Milhões) 1SEM 2SEM    0     1
# 1  Receita de vendas liquida  2.5  5.0  75%  100%
# 2          Custos e despesas  1.5  3.2  52%   89%
# 3     Despesas não previstas  1.2  1.4  12%   24%

# %%
# Vamos renomear as colunas do nosso DataFrame
tabela3.columns = ['DESCRICAO','1º SEMESTRE', '2º SEMESTRE', 'VAR_PERC_1_SEM','VAR_PERC_2_SEM']
tabela3
# Out:
#                    DESCRICAO 1º SEMESTRE 2º SEMESTRE VAR_PERC_1_SEM  \
# 1  Receita de vendas liquida         2.5         5.0            75%
# 2          Custos e despesas         1.5         3.2            52%
# 3     Despesas não previstas         1.2         1.4            12%
#
#   VAR_PERC_2_SEM
# 1           100%
# 2            89%
# 3            24%

# %%
# gravando os dados no formato xls.
tabela3.to_excel('Tabela_receita_2025.xlsx')

# %% [markdown]
# ### Agora vamos ler arquivo PDF que possua texto

# %%
# Carregando o arquivo PDF. Utilizamos inicialmente a função OPEN do Python porque precisamos carregar o arquivo como binário
arquivo_pdf = open('arquivo1.pdf', 'rb')

# %%
# !pip install 'PyPDF2<3.0'

# %%
# Lendo o arquivo PDF que foi carregado
pdf = PyPDF2.PdfReader(arquivo_pdf)

# %%
# Obtendo o número de páginas que foram carregadas
numero_paginas = len(pdf.pages)
numero_paginas
# Out:
# 1

# %%
# Obtendo a página que queremos visualizar
pagina = pdf.pages[0]

# %%
# Extraindo o conteúdo da página e exibindo
conteudo_pagina = pagina.extract_text()
conteudo_pagina
# Out:
# 'O que é ciência de dados?  \nA ciência de dados é o estudo dos dados para extrair insights significativos para os \nnegócios. Ela é uma abordagem multidisciplinar que combina princípios e práticas das \náreas de matemática, estatística, inteligência artificial e engenharia da computação p ara \nanalisar grandes quantidades de dados. Essa análise ajuda os cientistas de dados a fazer \ne responder perguntas como o que aconteceu, por que aconteceu, o que acontecerá e o \nque pode ser feito com os resultados.  \nPor que a ciência de dados é importante?  \nA ciência de dados é importante porque combina ferramentas, métodos e tecnologia para \ngerar significado com base em dados. As organizações modernas são inundadas com \ndados; há uma proliferação de dispositivos que podem coletar e armazenar informações \nautomaticamente. Sistemas online e portais de pagamento capturam mais dados nas \náreas de comércio eletrônico, medicina, finanças e todos os outros aspectos da vida \nhumana. Temos 
# ...

# %%
# Verificando o tipo da nossa variavel que foi carregado o conteúdo da página
type(conteudo_pagina)
# Out:
# str

# %%
# Visualizando o conteúdo da página com o comando print
print(conteudo_pagina)
# Out:
# O que é ciência de dados?
# A ciência de dados é o estudo dos dados para extrair insights significativos para os
# negócios. Ela é uma abordagem multidisciplinar que combina princípios e práticas das
# áreas de matemática, estatística, inteligência artificial e engenharia da computação p ara
# analisar grandes quantidades de dados. Essa análise ajuda os cientistas de dados a fazer
# e responder perguntas como o que aconteceu, por que aconteceu, o que acontecerá e o
# que pode ser feito com os resultados.
# Por que a ciência de dados é importante?
# A ciência de dados é importante porque combina ferramentas, métodos e tecnologia para
# gerar significado com base em dados. As organizações modernas são inundadas com
# dados; há uma proliferação de dispositivos que podem coletar e armazenar informações
# automaticamente. Sistemas online e portais de pagamento capturam mais dados nas
# áreas de comércio eletrônico, medicina, finanças e todos os outros aspectos da vida
# ...

# %%
# gravando os dados no formato xls.
conteudo_pagina.to_str('Ciencia-Dados.txt')

#PROCURAR O ERRO PARA FAZER CORRETO
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-262d9c2a65e9> in <cell line: 0>()
#       1 # gravando os dados no formato xls.
# ----> 2 conteudo_pagina.to_str('Ciencia-Dados.txt')
#       3
#       4 #PROCURAR O ERRO PARA FAZER CORRETO
#
# AttributeError: 'str' object has no attribute 'to_str'
